# %%
import pandas as pd
df=pd.read_csv("HR_comma_sep.csv")

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %%
from sklearn import preprocessing
LE=preprocessing.LabelEncoder()
df.salary=LE.fit_transform(df.salary)
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
from sklearn import preprocessing
LE=preprocessing.LabelEncoder()
df.Department=LE.fit_transform(df.Department)
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
def get_heatmap(df):
    #This function gives heatmap of all NaN values
    plt.figure(figsize=(6,4))
    sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
    plt.tight_layout()
    return plt.show()

get_heatmap(df)

# %%
df.tail()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years  Department  salary
# 14994                      0           8       1
# 14995                      0           8       1
# ...

# %%
#understanding the given dataset

# %%
df.shape
# Out:
# (14999, 10)

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
df.sample(5)
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 8561                 0.64             0.60               3
# 6283                 0.92             0.77               3
# 14822                0.39             0.53               2
# 6504                 0.56             0.50               3
# 11798                0.61             0.42               3
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 8561                    196                   3              0     0
# 6283                    236                   3              0     0
# 14822                   127                   3              0     1
# 6504                    156                   3              1     0
# 11798                   145                   4              0     0
#
#        promotion_last_5years  Department  salary
# 8561                       0           7       1
# 6283                       0           7       2
# ...

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
df.ndim
# Out:
# 2

# %%
df.dtypes
# Out:
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# Department                 int32
# salary                     int32
# dtype: object

# %%
df.count()
# Out:
# satisfaction_level       14999
# last_evaluation          14999
# number_project           14999
# average_montly_hours     14999
# time_spend_company       14999
# Work_accident            14999
# left                     14999
# promotion_last_5years    14999
# Department               14999
# salary                   14999
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14994     True
# 14995     True
# 14996     True
# 14997     True
# 14998     True
# Length: 14999, dtype: bool

# %%
df.mean()
# Out:
# satisfaction_level         0.612834
# last_evaluation            0.716102
# number_project             3.803054
# average_montly_hours     201.050337
# time_spend_company         3.498233
# Work_accident              0.144610
# left                       0.238083
# promotion_last_5years      0.021268
# Department                 5.870525
# salary                     1.347290
# dtype: float64

# %%
df.median()
# Out:
# satisfaction_level         0.64
# last_evaluation            0.72
# number_project             4.00
# average_montly_hours     200.00
# time_spend_company         3.00
# Work_accident              0.00
# left                       0.00
# promotion_last_5years      0.00
# Department                 7.00
# salary                     1.00
# dtype: float64

# %%
df.std()
# Out:
# satisfaction_level        0.248631
# last_evaluation           0.171169
# number_project            1.232592
# average_montly_hours     49.943099
# time_spend_company        1.460136
# Work_accident             0.351719
# left                      0.425924
# promotion_last_5years     0.144281
# Department                2.868786
# salary                    0.625819
# dtype: float64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=14999, step=1)

# %%
df.nunique()
# Out:
# satisfaction_level        92
# last_evaluation           65
# number_project             6
# average_montly_hours     215
# time_spend_company         8
# Work_accident              2
# left                       2
# promotion_last_5years      2
# Department                10
# salary                     3
# dtype: int64

# %%
df.corr()
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.105021       -0.142970
# last_evaluation                  0.105021         1.000000        0.349333
# number_project                  -0.142970         0.349333        1.000000
# average_montly_hours            -0.020048         0.339742        0.417211
# time_spend_company              -0.100866         0.131591        0.196786
# Work_accident                    0.058697        -0.007104       -0.004741
# left                            -0.388375         0.006567        0.023787
# promotion_last_5years            0.025605        -0.008684       -0.006064
# Department                       0.003153         0.007772        0.009268
# salary                           0.011754         0.013965        0.009672
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                -0.020048           -0.100866
# ...

# %%
#accessing the dataset

# %%
df[['number_project','time_spend_company']]#retrieving the 2 columns from dataset
# Out:
#        number_project  time_spend_company
# 0                   2                   3
# 1                   5                   6
# 2                   7                   4
# 3                   5                   5
# 4                   2                   3
# ...               ...                 ...
# 14994               2                   3
# 14995               2                   3
# 14996               2                   3
# 14997               6                   4
# 14998               2                   3
#
# [14999 rows x 2 columns]

# %%
df[2:5]#generating the rows 2 to 4
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  Department  \
# 2                   4              0     1                      0           7
# 3                   5              0     1                      0           7
# 4                   3              0     1                      0           7
#
#    salary
# 2       2
# 3       1
# 4       1

# %%
df.loc[:,:]#retreving all rows and columns
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.loc[[2000,3400,5000,4329],:]#retreiving all random rows and all columns
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# 2000                0.58             0.74               4
# 3400                0.98             0.60               2
# 5000                0.35             1.00               6
# 4329                0.46             0.43               4
#
#       average_montly_hours  time_spend_company  Work_accident  left  \
# 2000                   215                   3              0     0
# 3400                   249                   3              0     0
# 5000                   186                   2              0     0
# 4329                   258                   3              0     0
#
#       promotion_last_5years  Department  salary
# 2000                      0           7       1
# 3400                      0           9       1
# 5000                      0           9       1
# 4329                      0           8       1

# %%
df.loc[[2000,3400,5000,4329],['number_project','average_montly_hours']]#retreiving all random rows and columns
# Out:
#       number_project  average_montly_hours
# 2000               4                   215
# 3400               2                   249
# 5000               6                   186
# 4329               4                   258

# %%
df.iloc[:,:]
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
X=df.iloc[:,:-1].values
Y=df.iloc[:,1:].values
X
# Out:
# array([[0.38, 0.53, 2.  , ..., 1.  , 0.  , 7.  ],
#        [0.8 , 0.86, 5.  , ..., 1.  , 0.  , 7.  ],
#        [0.11, 0.88, 7.  , ..., 1.  , 0.  , 7.  ],
#        ...,
#        [0.37, 0.53, 2.  , ..., 1.  , 0.  , 8.  ],
#        [0.11, 0.96, 6.  , ..., 1.  , 0.  , 8.  ],
#        [0.37, 0.52, 2.  , ..., 1.  , 0.  , 8.  ]])

# %%
Y
# Out:
# array([[  0.53,   2.  , 157.  , ...,   0.  ,   7.  ,   1.  ],
#        [  0.86,   5.  , 262.  , ...,   0.  ,   7.  ,   2.  ],
#        [  0.88,   7.  , 272.  , ...,   0.  ,   7.  ,   2.  ],
#        ...,
#        [  0.53,   2.  , 143.  , ...,   0.  ,   8.  ,   1.  ],
#        [  0.96,   6.  , 280.  , ...,   0.  ,   8.  ,   1.  ],
#        [  0.52,   2.  , 158.  , ...,   0.  ,   8.  ,   1.  ]])

# %%
df.iloc[1000:1500,3:8]#retreiving the rows from 1000 to 1499 and columns from 3 to 7th column
# Out:
#       average_montly_hours  time_spend_company  Work_accident  left  \
# 1000                   258                   5              1     1
# 1001                   267                   4              0     1
# 1002                   141                   3              0     1
# 1003                   160                   3              0     1
# 1004                   247                   4              0     1
# ...                    ...                 ...            ...   ...
# 1495                   247                   5              0     1
# 1496                   259                   4              0     1
# 1497                   129                   3              0     1
# 1498                   152                   3              0     1
# 1499                   128                   3              0     1
#
#       promotion_last_5years
# 1000                      1
# 1001                      0
# 1002                      0
# 1003                      0
# ...

# %%
df[df['number_project']>4].loc[4:15,'number_project']#generating the whose projects id graeter than from 4 to 15 records
# Out:
# 6     6
# 7     5
# 8     5
# 11    6
# Name: number_project, dtype: int64

# %%
df[df['number_project']>4].iloc[:,2]#generating the whose projects id graeter than 4 for all records
# Out:
# 1        5
# 2        7
# 3        5
# 6        6
# 7        5
#         ..
# 14987    5
# 14990    5
# 14991    6
# 14993    6
# 14997    6
# Name: number_project, Length: 4191, dtype: int64

# %%
#Data manipulation

# %%
data=df.rename({'number_project':'projects'},axis=1)
data
# Out:
#        satisfaction_level  last_evaluation  projects  average_montly_hours  \
# 0                    0.38             0.53         2                   157
# 1                    0.80             0.86         5                   262
# 2                    0.11             0.88         7                   272
# 3                    0.72             0.87         5                   223
# 4                    0.37             0.52         2                   159
# ...                   ...              ...       ...                   ...
# 14994                0.40             0.57         2                   151
# 14995                0.37             0.48         2                   160
# 14996                0.37             0.53         2                   143
# 14997                0.11             0.96         6                   280
# 14998                0.37             0.52         2                   158
#
# ...

# %%
data=df.drop(columns=['number_project'])
data
# Out:
#        satisfaction_level  last_evaluation  average_montly_hours  \
# 0                    0.38             0.53                   157
# 1                    0.80             0.86                   262
# 2                    0.11             0.88                   272
# 3                    0.72             0.87                   223
# 4                    0.37             0.52                   159
# ...                   ...              ...                   ...
# 14994                0.40             0.57                   151
# 14995                0.37             0.48                   160
# 14996                0.37             0.53                   143
# 14997                0.11             0.96                   280
# 14998                0.37             0.52                   158
#
#        time_spend_company  Work_accident  left  promotion_last_5years  \
# 0                       3              0     1                      0
# ...

# %%
#checking for missing values

# %%
df.isna()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                   False            False           False
# 1                   False            False           False
# 2                   False            False           False
# 3                   False            False           False
# 4                   False            False           False
# ...                   ...              ...             ...
# 14994               False            False           False
# 14995               False            False           False
# 14996               False            False           False
# 14997               False            False           False
# 14998               False            False           False
#
#        average_montly_hours  time_spend_company  Work_accident   left  \
# 0                     False               False          False  False
# 1                     False               False          False  False
# ...

# %%
df.isna().any()
# Out:
# satisfaction_level       False
# last_evaluation          False
# number_project           False
# average_montly_hours     False
# time_spend_company       False
# Work_accident            False
# left                     False
# promotion_last_5years    False
# Department               False
# salary                   False
# dtype: bool

# %%
df.isna().sum()#number of null values in each column
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %%
df.isna().all()
# Out:
# satisfaction_level       False
# last_evaluation          False
# number_project           False
# average_montly_hours     False
# time_spend_company       False
# Work_accident            False
# left                     False
# promotion_last_5years    False
# Department               False
# salary                   False
# dtype: bool

# %%
df.columns[df.isna().any()]#generate the only columns which is having only null values
# Out:
# Index([], dtype='object')

# %%
#Data visulaization

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
df.number_project.value_counts().plot.bar() #the bargraph for number of projects done
# Out:
# <AxesSubplot:>

# %%
df.number_project.value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
df.count().plot.area()
# Out:
# <AxesSubplot:>

# %%
df.plot.area()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
plt.bar(df.satisfaction_level,df.last_evaluation)
plt.show()

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14340/964094849.py in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt
plt.bar(df.number_projects,df.salary)
plt.show()

# %%
#histogram

# %%
import seaborn as sn
sn.histplot(df.number_project)
# Out:
# <AxesSubplot:xlabel='number_project', ylabel='Count'>

# %%
sn.histplot(df.satisfaction_level)
# Out:
# <AxesSubplot:xlabel='satisfaction_level', ylabel='Count'>

# %%
sn.histplot(df.last_evaluation)
# Out:
# <AxesSubplot:xlabel='last_evaluation', ylabel='Count'>

# %%
sn.histplot(df.average_montly_hours)
# Out:
# <AxesSubplot:xlabel='average_montly_hours', ylabel='Count'>

# %%
sn.histplot(df.time_spend_company)
# Out:
# <AxesSubplot:xlabel='time_spend_company', ylabel='Count'>

# %%
sn.histplot(df.Work_accident)
# Out:
# <AxesSubplot:xlabel='Work_accident', ylabel='Count'>

# %%
sn.histplot(df.promotion_last_5years)
# Out:
# <AxesSubplot:xlabel='promotion_last_5years', ylabel='Count'>

# %%
sn.histplot(df.Department)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='Count'>

# %%
sn.histplot(df.salary)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Count'>

# %%
#bargraphs

# %%
df.count().plot.bar()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,6))
plt.title('projects and time analysis')
plt.xlabel("projects")
plt.ylabel("time spend")
plt.bar(df.number_project,df.time_spend_company)
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(6,6))
plt.title('projects and time analysis')
plt.xlabel("projects")
plt.ylabel("time spend")
sns.barplot(df.number_project,df.time_spend_company)
plt.show()
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
plt.figure(figsize=(6,6))
plt.title('projects and work analysis')
plt.xlabel("projects")
plt.ylabel("work accidents")
sns.barplot(df.number_project,df.Work_accident)
plt.show()
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
plt.figure(figsize=(6,6))
plt.title('projects and department')
plt.xlabel("departmnet")
plt.ylabel("projects")
sns.barplot(df.Department,df.number_project)
plt.show()
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
plt.figure(figsize=(6,6))
plt.title('projects and monthly hours')
plt.xlabel("project")
plt.ylabel("monthly hours")
sns.barplot(df.number_project,df.average_montly_hours)
plt.show()
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
plt.figure(figsize=(6,6))
plt.title('projects and satisfaction level')
plt.xlabel("project")
plt.ylabel("satisfaction ")
sns.barplot(df.number_project,df.satisfaction_level)
plt.show()
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
plt.figure(figsize=(6,6))
plt.title('projects and last evaluation')
plt.xlabel("project")
plt.ylabel("last evaluation ")
sns.barplot(df.number_project,df.last_evaluation)
plt.show()
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
plt.figure(figsize=(6,6))
plt.title('projects and left')
plt.xlabel("projects")
plt.ylabel("left")
sns.barplot(df.number_project,df.left)
plt.show()
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
plt.figure(figsize=(6,6))
plt.title('time and monthly hours')
plt.xlabel("time")
plt.ylabel("monthly")
sns.barplot(df.time_spend_company,df.average_montly_hours)
plt.show()
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
plt.figure(figsize=(6,6))
plt.title('work and time')
plt.xlabel("time")
plt.ylabel("work")
sns.barplot(df.time_spend_company,df.Work_accident)
plt.show()
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
plt.figure(figsize=(6,6))
plt.title('time and promtion')
plt.xlabel("time")
plt.ylabel("promtion")
sns.barplot(df.time_spend_company,df.promotion_last_5years)
plt.show()
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
plt.figure(figsize=(6,6))
plt.title('department and time')
plt.xlabel("time")
plt.ylabel("Department")
sns.barplot(df.time_spend_company,df.Department)
plt.show()
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
plt.figure(figsize=(6,6))
plt.title('work an dpromtion')
plt.xlabel("work")
plt.ylabel("promtion")
sns.barplot(df.Work_accident,df.promotion_last_5years)
plt.show()
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
plt.figure(figsize=(6,6))
plt.title('work an monthly')
plt.xlabel("work")
plt.ylabel("monthly")
sns.barplot(df.Work_accident,df.average_montly_hours)
plt.show()
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Scatter plot

# %%
import seaborn as sns
sns.scatterplot(df.number_project,df.Work_accident)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='number_project', ylabel='Work_accident'>

# %%
sns.scatterplot(df.number_project,df.time_spend_company)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='number_project', ylabel='time_spend_company'>

# %%
sns.scatterplot(df.number_project,df.satisfaction_level)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='number_project', ylabel='satisfaction_level'>

# %%
sns.scatterplot(df.number_project,df.Department)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='number_project', ylabel='Department'>

# %%
sns.scatterplot(df.number_project,df.average_montly_hours)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='number_project', ylabel='average_montly_hours'>

# %%
sns.scatterplot(df.	satisfaction_level,df.average_montly_hours)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='satisfaction_level', ylabel='average_montly_hours'>

# %%
sns.scatterplot(df.	satisfaction_level,df.last_evaluation)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='satisfaction_level', ylabel='last_evaluation'>

# %%
sns.scatterplot(df.	satisfaction_level,df.average_montly_hours)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='satisfaction_level', ylabel='average_montly_hours'>

# %%
sns.scatterplot(df.satisfaction_level,df.time_spend_company)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='satisfaction_level', ylabel='time_spend_company'>

# %%
sns.scatterplot(df.satisfaction_level,df.Work_accident)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='satisfaction_level', ylabel='Work_accident'>

# %%
sns.scatterplot(df.satisfaction_level,df.promotion_last_5years)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='satisfaction_level', ylabel='promotion_last_5years'>

# %%
sns.scatterplot(df.last_evaluation,df.promotion_last_5years)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='last_evaluation', ylabel='promotion_last_5years'>

# %%
sns.scatterplot(df.last_evaluation,df.Work_accident)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='last_evaluation', ylabel='Work_accident'>

# %%
sns.scatterplot(df.last_evaluation,df.time_spend_company)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='last_evaluation', ylabel='time_spend_company'>

# %%
sns.scatterplot(df.last_evaluation,df.average_montly_hours)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='last_evaluation', ylabel='average_montly_hours'>

# %%
sns.scatterplot(df.last_evaluation,df.left)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='last_evaluation', ylabel='left'>

# %%
sns.scatterplot(df.time_spend_company,df.left)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='time_spend_company', ylabel='left'>

# %%
sns.scatterplot(df.time_spend_company,df.average_montly_hours)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='time_spend_company', ylabel='average_montly_hours'>

# %%
sns.scatterplot(df.time_spend_company,df.promotion_last_5years)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='time_spend_company', ylabel='promotion_last_5years'>

# %%
sns.scatterplot(df.average_montly_hours,df.promotion_last_5years)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='average_montly_hours', ylabel='promotion_last_5years'>

# %%
#Strip plot

# %%
sns.stripplot(df.number_project,df.Department)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='number_project', ylabel='Department'>

# %%
sns.stripplot(df.satisfaction_level,df.Department)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='satisfaction_level', ylabel='Department'>

# %%
sns.stripplot(df.last_evaluation,df.Department)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='last_evaluation', ylabel='Department'>

# %%
sns.stripplot(df.average_montly_hours,df.Department)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='average_montly_hours', ylabel='Department'>

# %%
sns.stripplot(df.time_spend_company,df.Department)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='time_spend_company', ylabel='Department'>

# %%
sns.stripplot(df.promotion_last_5years,df.Department)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='promotion_last_5years', ylabel='Department'>

# %%
#pair plot

# %%
sns.pairplot(data=df)#plot all numeric category

# %%
#lineplot

# %%
sns.lineplot(data=df)
# Out:
# <AxesSubplot:>

# %%
#viloin plot(combination of density plot and boxplot)

# %%
sns.violinplot(data=df)
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(df.number_project)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='number_project'>

# %%
sns.violinplot(df.time_spend_company)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='time_spend_company'>

# %%
sns.violinplot(df.Work_accident)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Work_accident'>

# %%
sns.violinplot(df.average_montly_hours)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='average_montly_hours'>

# %%
sns.violinplot(df.last_evaluation)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='last_evaluation'>

# %%
sns.violinplot(df.satisfaction_level)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='satisfaction_level'>

# %%
#point plot

# %%
sns.pointplot(data=df)
# Out:
# <AxesSubplot:>

# %%
sns.pointplot(df.satisfaction_level)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='satisfaction_level'>

# %%
sns.pointplot(df.last_evaluation)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='last_evaluation'>

# %%
sns.pointplot(df.number_project)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='number_project'>

# %%
sns.pointplot(df.time_spend_company)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='time_spend_company'>

# %%
#Regression plot

# %%
sns.regplot(df.satisfaction_level,df.number_project)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='satisfaction_level', ylabel='number_project'>

# %%
sns.regplot(df.number_project,df.average_montly_hours)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='number_project', ylabel='average_montly_hours'>

# %%
sns.regplot(df.number_project,df.time_spend_company)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='number_project', ylabel='time_spend_company'>

# %%
sns.regplot(df.number_project,df.promotion_last_5years)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='number_project', ylabel='promotion_last_5years'>

# %%
sns.regplot(df.number_project,df.last_evaluation)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='number_project', ylabel='last_evaluation'>

# %%
#Realtion plot

# %%
sns.relplot(df.satisfaction_level,df.number_project)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot(df.number_project,df.average_montly_hours)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot(df.number_project,df.time_spend_company)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.relplot(df.number_project,df.promotion_last_5years)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Kernal density estimation plot

# %%
sns.kdeplot(df.number_project)
# Out:
# <AxesSubplot:xlabel='number_project', ylabel='Density'>

# %%
sns.kdeplot(df.last_evaluation)
# Out:
# <AxesSubplot:xlabel='last_evaluation', ylabel='Density'>

# %%
sns.kdeplot(df.satisfaction_level)
# Out:
# <AxesSubplot:xlabel='satisfaction_level', ylabel='Density'>

# %%
sns.kdeplot(df.average_montly_hours)
# Out:
# <AxesSubplot:xlabel='average_montly_hours', ylabel='Density'>

# %%
sns.kdeplot(df.	time_spend_company)
# Out:
# <AxesSubplot:xlabel='time_spend_company', ylabel='Density'>

# %%
sns.kdeplot(df.promotion_last_5years)
# Out:
# <AxesSubplot:xlabel='promotion_last_5years', ylabel='Density'>

# %%
#boxplot
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  Department  \
# 0                   3              0     1                      0           7
# 1                   6              0     1                      0           7
# 2                   4              0     1                      0           7
# 3                   5              0     1                      0           7
# 4                   3              0     1                      0           7
#
#    salary
# 0       1
# 1       2
# ...

# %%
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(df.number_project)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='number_project'>

# %%
sns.boxplot(df.	satisfaction_level)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='satisfaction_level'>

# %%
sns.boxplot(df.last_evaluation)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='last_evaluation'>

# %%
sns.boxplot(df.	average_montly_hours)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='average_montly_hours'>

# %%
sns.boxplot(df.time_spend_company)
# Out:
# C:\Users\kotad\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='time_spend_company'>

# %%
from sklearn import preprocessing
LE=preprocessing.LabelEncoder()
df.salary=LE.fit_transform(df.salary)
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  Department  \
# 0                   3              0     1                      0           7
# 1                   6              0     1                      0           7
# 2                   4              0     1                      0           7
# 3                   5              0     1                      0           7
# 4                   3              0     1                      0           7
#
#    salary
# 0       1
# 1       2
# ...

# %%
import numpy as np
train_x= np.array(data[["satisfaction_level"]])
train_y = np.array(data[["salary"]])
print(train_x)
# Out:
# [[0.38]
#  [0.8 ]
#  [0.11]
#  ...
#  [0.37]
#  [0.11]
#  [0.37]]

# %%
import numpy as np
train_x= np.array(data[["last_evaluation"]])
train_y = np.array(data[["salary"]])
print(train_x)
# Out:
# [[0.53]
#  [0.86]
#  [0.88]
#  ...
#  [0.53]
#  [0.96]
#  [0.52]]

# %%
import numpy as np
train_x= np.array(data[["average_montly_hours"]])
train_y = np.array(data[["salary"]])
print(train_x)
# Out:
# [[157]
#  [262]
#  [272]
#  ...
#  [143]
#  [280]
#  [158]]

# %%
import numpy as np
train_x= np.array(data[["Work_accident"]])
train_y = np.array(data[["salary"]])
print(train_x)
# Out:
# [[0]
#  [0]
#  [0]
#  ...
#  [0]
#  [0]
#  [0]]

# %%
import numpy as np
train_x= np.array(data[["Department"]])
train_y = np.array(data[["salary"]])
print(train_x)
# Out:
# [[7]
#  [7]
#  [7]
#  ...
#  [8]
#  [8]
#  [8]]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)

# %%
X_train
# Out:
# array([[0.87, 0.74, 4.  , ..., 0.  , 0.  , 5.  ],
#        [0.4 , 0.46, 2.  , ..., 1.  , 0.  , 9.  ],
#        [0.66, 0.84, 4.  , ..., 0.  , 0.  , 3.  ],
#        ...,
#        [0.38, 0.46, 2.  , ..., 1.  , 0.  , 9.  ],
#        [0.78, 0.67, 4.  , ..., 0.  , 0.  , 8.  ],
#        [0.43, 0.51, 2.  , ..., 1.  , 0.  , 2.  ]])

# %%
X_test
# Out:
# array([[0.7 , 0.9 , 4.  , ..., 0.  , 0.  , 0.  ],
#        [0.39, 0.52, 2.  , ..., 0.  , 0.  , 9.  ],
#        [0.41, 0.49, 2.  , ..., 1.  , 0.  , 7.  ],
#        ...,
#        [0.37, 0.56, 2.  , ..., 1.  , 0.  , 7.  ],
#        [0.87, 0.71, 5.  , ..., 0.  , 0.  , 0.  ],
#        [0.65, 0.37, 5.  , ..., 0.  , 0.  , 6.  ]])

# %%
Y_train
# Out:
# array([[  0.74,   4.  , 265.  , ...,   0.  ,   5.  ,   2.  ],
#        [  0.46,   2.  , 149.  , ...,   0.  ,   9.  ,   2.  ],
#        [  0.84,   4.  , 197.  , ...,   0.  ,   3.  ,   1.  ],
#        ...,
#        [  0.46,   2.  , 137.  , ...,   0.  ,   9.  ,   1.  ],
#        [  0.67,   4.  , 221.  , ...,   0.  ,   8.  ,   1.  ],
#        [  0.51,   2.  , 149.  , ...,   0.  ,   2.  ,   2.  ]])

# %%
Y_test
# Out:
# array([[  0.9 ,   4.  , 254.  , ...,   0.  ,   0.  ,   2.  ],
#        [  0.52,   2.  , 102.  , ...,   0.  ,   9.  ,   2.  ],
#        [  0.49,   2.  , 147.  , ...,   0.  ,   7.  ,   1.  ],
#        ...,
#        [  0.56,   2.  , 156.  , ...,   0.  ,   7.  ,   2.  ],
#        [  0.71,   5.  , 244.  , ...,   0.  ,   0.  ,   1.  ],
#        [  0.37,   5.  , 128.  , ...,   0.  ,   6.  ,   2.  ]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.1,random_state=3)

# %%
X_train
# Out:
# array([[0.1 , 0.88, 6.  , ..., 1.  , 0.  , 7.  ],
#        [0.66, 0.92, 2.  , ..., 0.  , 0.  , 6.  ],
#        [0.99, 0.98, 4.  , ..., 0.  , 0.  , 9.  ],
#        ...,
#        [0.98, 0.49, 3.  , ..., 0.  , 0.  , 9.  ],
#        [0.41, 0.48, 2.  , ..., 1.  , 0.  , 5.  ],
#        [0.8 , 0.99, 4.  , ..., 0.  , 0.  , 9.  ]])

# %%
x=np.array(data_scaled[['maxTemp','minTemp','avgHumidity','Rainfall']])

y=np.array(data_scaled[['Class']])

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11032/4153405994.py in <module>
# ----> 1 model.fit(X_train,Y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1342             _dtype = [np.float64, np.float32]
#    1343
# -> 1344         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ...

# %%
import numpy as np
Y_pred=model.predict(Y_test)
np.set_printoptions(precision=2)
print(np.concatenate((Y_pred.reshape(len(Y_pred),1),Y_test.reshape(len(Y_test),1)),1))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11032/2134277968.py in <module>
#       1 import numpy as np
# ----> 2 Y_pred=model.predict(Y_test)
#       3 np.set_printoptions(precision=2)
#       4 print(np.concatenate((Y_pred.reshape(len(Y_pred),1),Y_test.reshape(len(Y_test),1)),1))
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     307             Predicted class label per sample.
#     308         """
# --> 309         scores = self.decision_function(X)
#     310         if len(scores.shape) == 1:
#     311             indices = (scores > 0).astype(int)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in decision_function(self, X)
#     280             class would be predicted.
#     281         """
# --> 282         check_is_fitted(self)
#     283
# ...

# %%
model.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11032/4153405994.py in <module>
# ----> 1 model.fit(X_train,Y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1342             _dtype = [np.float64, np.float32]
#    1343
# -> 1344         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ...
